# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# Pandas is a library for managing large datasets in tabular format. It is powerful with lots of functionality and is very fast.
#
# We cover loading data and then Pandas data cleaning and organisation commands
#
# Pandas gets very powerful when the volume of data is too big for Excel

# %%
# We load Pandas and prefix all of its commands with pd
import pandas as pd

# %% [markdown]
# ## The DataFrame

# %%
df = pd.DataFrame([1,3,5,7], columns = ['odd'], index = ['a','b','c','d'])
df
# Out:
#    odd
# a    1
# b    3
# c    5
# d    7

# %%
df['even'] = [2,4,6,8]

# %%
df
# Out:
#    odd  even
# a    1     2
# b    3     4
# c    5     6
# d    7     8

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['odd', 'even'], dtype='object')

# %%
df.head()
# Out:
#    odd  even
# a    1     2
# b    3     4
# c    5     6
# d    7     8

# %%
df.loc['a']
# Out:
# odd     1
# even    2
# Name: a, dtype: int64

# %%
df.iloc[0]
# Out:
# odd     1
# even    2
# Name: a, dtype: int64

# %%
df['odd']
# Out:
# a    1
# b    3
# c    5
# d    7
# Name: odd, dtype: int64

# %%
df['square'] = [1,2,4,16]

# %%
df
# Out:
#    odd  even  square
# a    1     2       1
# b    3     4       2
# c    5     6       4
# d    7     8      16

# %%
# We can use column name to access it as follows
df.odd
# Out:
# a    1
# b    3
# c    5
# d    7
# Name: odd, dtype: int64

# %%
# We can use column name to access it as follows
df.square
# Out:
# a     1
# b     2
# c     4
# d    16
# Name: square, dtype: int64

# %%
df.shape
# Out:
# (4, 3)

# %% [markdown]
# ## Loading a Large Dataset

# %% [markdown]
# Let's consider a larger data set

# %%
# We read the file into the data frame in one go
# Pandas always assumes that the first row is the header
df = pd.read_csv("./data/optionPortfolio.csv")

# %%
df.columns
# Out:
# Index(['TradeDate', 'Currency', 'Ticker', 'OptionType', 'TradedStockPrice',
#        'NumOptions', 'Strike', 'ExpiryDate'],
#       dtype='object')

# %%
df.head()
# Out:
#     TradeDate Currency Ticker OptionType  TradedStockPrice  NumOptions  \
# 0  2013-01-02      USD    PUT         BA         77.070000          60
# 1  2013-01-02      USD    PUT        XRX         18.945982         330
# 2  2013-01-02      USD   CALL        CHK         15.704825         230
# 3  2013-01-02      USD    PUT         FB         28.000000         340
# 4  2013-01-02      USD    PUT       MSFT         27.620001         690
#
#    Strike  ExpiryDate
# 0      77  2013-07-01
# 1      19  2013-07-01
# 2      15  2013-04-02
# 3      28  2013-12-28
# 4      26  2013-12-28

# %%
# There is a mislabelled column - let's fix it
df.columns = ['TradeDate', 'Currency', 'OptionType', 'Ticker', 'TradedStockPrice',
       'NumOptions', 'Strike', 'ExpiryDate']

# %%
# What is this ?
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# We can see the size of the data frame
df.shape
# Out:
# (4198, 8)

# %%
# head gives us the first 5 rows 
df.head()
# Out:
#     TradeDate Currency OptionType Ticker  TradedStockPrice  NumOptions  \
# 0  2013-01-02      USD        PUT     BA         77.070000          60
# 1  2013-01-02      USD        PUT    XRX         18.945982         330
# 2  2013-01-02      USD       CALL    CHK         15.704825         230
# 3  2013-01-02      USD        PUT     FB         28.000000         340
# 4  2013-01-02      USD        PUT   MSFT         27.620001         690
#
#    Strike  ExpiryDate
# 0      77  2013-07-01
# 1      19  2013-07-01
# 2      15  2013-04-02
# 3      28  2013-12-28
# 4      26  2013-12-28

# %% [markdown]
# ## Preparing the Data

# %%
# Look for missing data by getting info on all of the columns
# Make sure all the fields have the correct data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4198 entries, 0 to 4197
# Data columns (total 8 columns):
# TradeDate           4198 non-null object
# Currency            4198 non-null object
# OptionType          4198 non-null object
# Ticker              4198 non-null object
# TradedStockPrice    4198 non-null float64
# NumOptions          4198 non-null int64
# Strike              4198 non-null int64
# ExpiryDate          4198 non-null object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 262.5+ KB

# %%
df = df.drop(['Currency'],axis=1)

# %%
type(df_ccy)
# Out:
# pandas.core.series.Series

# %%
df['OptionType'].unique()
# Out:
# array(['PUT', 'CALL'], dtype=object)

# %%
df['Ticker'].value_counts()
# Out:
# XRX     589
# MSFT    586
# CHK     584
# BA      554
# FB      548
# AMZN    544
# AAPL    528
# BLCM    265
# Name: Ticker, dtype: int64

# %% [markdown]
# ## Examining the Dataframe

# %%
# We can convert the data frame to a Numpy array 
m = df.values

# %%
type(m)
# Out:
# numpy.ndarray

# %%
m[10,4]
# Out:
# 640

# %%
# To get the first 8 rows we can use iloc
df.iloc[1:9]
# Out:
#     TradeDate OptionType Ticker  TradedStockPrice  NumOptions  Strike  \
# 1  2013-01-02        PUT    XRX         18.945982         330      19
# 2  2013-01-02       CALL    CHK         15.704825         230      15
# 3  2013-01-02        PUT     FB         28.000000         340      28
# 4  2013-01-02        PUT   MSFT         27.620001         690      26
# 5  2013-01-02        PUT     FB         28.000000         240      26
# 6  2013-01-02       CALL     FB         28.000000         590      28
# 7  2013-01-03       CALL    XRX         18.945982           0      19
# 8  2013-01-03       CALL   AMZN        258.480011         450     249
#
#    ExpiryDate
# 1  2013-07-01
# 2  2013-04-02
# 3  2013-12-28
# 4  2013-12-28
# 5  2013-07-01
# 6  2013-12-28
# 7  2013-04-03
# 8  2013-07-02

# %% [markdown]
# ## Apply

# %% [markdown]
# The trade date is in a string form

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
# TradeDate           4198 non-null object
# OptionType          4198 non-null object
# Ticker              4198 non-null object
# TradedStockPrice    4198 non-null float64
# NumOptions          4198 non-null int64
# Strike              4198 non-null int64
# ExpiryDate          4198 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 229.7+ KB

# %%
# We write a quick function to remove the '/' from the date and to replace it with a space
# We could have done this another way but I 
def dateConverter(dt):
    dt = dt.replace('-',' ')
    return pd.to_datetime(dt, format='%Y %m %d',dayfirst=True)

# %%
# The apply function let's us do something complicated to a column 
df['TradeDate'] = df['TradeDate'].apply(dateConverter)

# %%
df['ExpiryDate'] = df['ExpiryDate'].apply(dateConverter)

# %%
# The date is now a datetime 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
# TradeDate           4198 non-null datetime64[ns]
# OptionType          4198 non-null object
# Ticker              4198 non-null object
# TradedStockPrice    4198 non-null float64
# NumOptions          4198 non-null int64
# Strike              4198 non-null int64
# ExpiryDate          4198 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(2)
# memory usage: 229.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
# TradeDate           4198 non-null datetime64[ns]
# OptionType          4198 non-null object
# Ticker              4198 non-null object
# TradedStockPrice    4198 non-null float64
# NumOptions          4198 non-null int64
# Strike              4198 non-null int64
# ExpiryDate          4198 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(2)
# memory usage: 229.7+ KB

# %% [markdown]
# ## Filters

# %%
df[df['OptionType'] == "PUT"].head()
# Out:
#    TradeDate OptionType Ticker  TradedStockPrice  NumOptions  Strike  \
# 0 2013-01-02        PUT     BA         77.070000          60      77
# 1 2013-01-02        PUT    XRX         18.945982         330      19
# 3 2013-01-02        PUT     FB         28.000000         340      28
# 4 2013-01-02        PUT   MSFT         27.620001         690      26
# 5 2013-01-02        PUT     FB         28.000000         240      26
#
#   ExpiryDate
# 0 2013-07-01
# 1 2013-07-01
# 3 2013-12-28
# 4 2013-12-28
# 5 2013-07-01

# %%
df[(df['Ticker'] == "AAPL") & (df['OptionType'] == "PUT")].head()
# Out:
#     TradeDate OptionType Ticker  TradedStockPrice  NumOptions  Strike  \
# 18 2013-01-08        PUT   AAPL         75.044289         650      75
# 29 2013-01-14        PUT   AAPL         71.678574         940      73
# 34 2013-01-16        PUT   AAPL         72.298569         250      72
# 44 2013-01-22        PUT   AAPL         72.110001         530      74
# 47 2013-01-22        PUT   AAPL         72.110001         490      70
#
#    ExpiryDate
# 18 2013-04-08
# 29 2014-01-09
# 34 2014-01-11
# 44 2013-04-22
# 47 2013-07-21

# %%
import datetime as dt
df[(df['ExpiryDate'] < dt.datetime(2013,10,2)) & (df['OptionType'] == "PUT")]
# Out:
#      TradeDate OptionType Ticker  TradedStockPrice  NumOptions  Strike  \
# 0   2013-01-02        PUT     BA         77.070000          60      77
# 1   2013-01-02        PUT    XRX         18.945982         330      19
# 5   2013-01-02        PUT     FB         28.000000         240      26
# 11  2013-01-07        PUT    CHK         16.669821         820      17
# 17  2013-01-08        PUT     FB         29.059999         480      29
# 18  2013-01-08        PUT   AAPL         75.044289         650      75
# 20  2013-01-08        PUT   AMZN        266.380005          90     266
# 22  2013-01-08        PUT   AMZN        266.380005          20     267
# 26  2013-01-11        PUT   AMZN        267.940002         580     273
# 30  2013-01-14        PUT     BA         76.550003         190      76
# 31  2013-01-14        PUT   AMZN        272.730011         300     277
# 33  2013-01-16        PUT     FB         29.850000         820      29
# 37  2013-01-17        PUT     FB         30.139999         660      30
# 39  2013-01-17        PUT    XRX         19.973650         780      19
# 41  2013-01-18        PUT    CHK         16.859035         300      16
# 44  2013-01-22        PUT   AAPL         72.110001         530      74
# 47  2013-01-22        PUT   AAPL         72.110001         490      70
# 50  2013-01-23        PUT    CHK         17.502365         270      16
# 51  2013-01-23        PUT   AAPL         73.430000         430      73
# 52  2013-01-23        PUT     FB         30.820000         570      29
# 53  2013-01-23        PUT     BA         74.290001         230      75
# 54  2013-01-23        PUT   MSFT         27.610001         870      28
# 56  2013-01-24        PUT    XRX         20.421608         700      21
# 62  2013-01-25        PUT     FB         31.540001         420      31
# 64  2013-01-28        PUT   MSFT         27.910000         840      26
# 68  2013-01-29        PUT   AAPL         65.467140         650      63
# 71  2013-01-30        PUT   MSFT         27.850000         990      27
# 75  2013-01-31        PUT     FB         30.980000         340      30
# 76  2013-01-31        PUT   AMZN        265.500000         730     274
# 77  2013-01-31        PUT     BA         73.870003         550      76
# ..         ...        ...    ...               ...         ...     ...
# 315 2013-04-23        PUT    CHK         17.918638         500      17
# 317 2013-04-25        PUT   MSFT         31.940001         740      30
# 326 2013-04-26        PUT   AAPL         59.599998         520      57
# 327 2013-04-26        PUT    XRX         22.081686         740      22
# 328 2013-04-29        PUT   MSFT         32.610001         730      31
# 338 2013-05-01        PUT   AAPL         62.755714         400      62
# 342 2013-05-03        PUT    CHK         18.211920         540      18
# 346 2013-05-08        PUT   AAPL         66.262856         190      63
# 356 2013-05-13        PUT   AAPL         64.962860         560      63
# 357 2013-05-13        PUT    XRX         23.425560          60      24
# 360 2013-05-13        PUT     BA         94.760002         250      95
# 361 2013-05-13        PUT     BA         94.760002         780      94
# 365 2013-05-14        PUT   AMZN        268.329987         210     267
# 368 2013-05-14        PUT   AAPL         63.408573         920      63
# 369 2013-05-14        PUT    CHK         19.640491         130      19
# 372 2013-05-17        PUT   MSFT         34.869999           0      36
# 388 2013-05-21        PUT   AMZN        268.859985         130     274
# 393 2013-05-23        PUT   MSFT         34.150002         800      33
# 403 2013-05-28        PUT     FB         24.100000         110      23
# 414 2013-05-30        PUT     FB         24.549999         220      24
# 417 2013-05-30        PUT     BA        100.540001         120      95
# 430 2013-06-04        PUT   AMZN        265.700012         360     269
# 441 2013-06-07        PUT   AMZN        276.869995         240     267
# 454 2013-06-12        PUT   AMZN        271.670013         220     281
# 459 2013-06-18        PUT   AMZN        281.760010          90     295
# 461 2013-06-18        PUT   AAPL         61.681427         240      64
# 469 2013-06-20        PUT    CHK         18.997162         740      19
# 470 2013-06-21        PUT     FB         24.530001         430      24
# 486 2013-06-26        PUT     FB         24.160000         400      23
# 488 2013-06-26        PUT     BA        100.750000         420      98
#
#     ExpiryDate
# 0   2013-07-01
# 1   2013-07-01
# 5   2013-07-01
# 11  2013-04-07
# 17  2013-07-07
# 18  2013-04-08
# 20  2013-04-08
# 22  2013-07-07
# 26  2013-04-11
# 30  2013-07-13
# 31  2013-04-14
# 33  2013-04-16
# 37  2013-04-17
# 39  2013-07-16
# 41  2013-04-18
# 44  2013-04-22
# 47  2013-07-21
# 50  2013-07-22
# 51  2013-04-23
# 52  2013-04-23
# 53  2013-07-22
# 54  2013-04-23
# 56  2013-04-24
# 62  2013-07-24
# 64  2013-07-27
# 68  2013-07-28
# 71  2013-07-29
# 75  2013-05-01
# 76  2013-05-01
# 77  2013-05-01
# ..         ...
# 315 2013-07-22
# 317 2013-07-24
# 326 2013-07-25
# 327 2013-07-25
# 328 2013-07-28
# 338 2013-07-30
# 342 2013-08-01
# 346 2013-08-06
# 356 2013-08-11
# 357 2013-08-11
# 360 2013-08-11
# 361 2013-08-11
# 365 2013-08-12
# 368 2013-08-12
# 369 2013-08-12
# 372 2013-08-15
# 388 2013-08-19
# 393 2013-08-21
# 403 2013-08-26
# 414 2013-08-28
# 417 2013-08-28
# 430 2013-09-02
# 441 2013-09-05
# 454 2013-09-10
# 459 2013-09-16
# 461 2013-09-16
# 469 2013-09-18
# 470 2013-09-19
# 486 2013-09-24
# 488 2013-09-24
#
# [126 rows x 7 columns]

# %% [markdown]
# ## Group By

# %% [markdown]
# This enables us to do a breakdown by a particular field

# %%
df[['NumOptions','Ticker']].groupby(['Ticker']).count()
# Out:
#         NumOptions
# Ticker
# AAPL           528
# AMZN           544
# BA             554
# BLCM           265
# CHK            584
# FB             548
# MSFT           586
# XRX            589

# %%
df[['Strike','Ticker']].groupby(['Ticker']).mean()
# Out:
#             Strike
# Ticker
# AAPL     95.448864
# AMZN    450.220588
# BA      125.481949
# BLCM     16.909434
# CHK      15.393836
# FB       75.682482
# MSFT     44.013652
# XRX      27.806452
